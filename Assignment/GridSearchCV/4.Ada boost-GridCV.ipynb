# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[10,20,30,50],'learning_rate':[0.1,0.01,0.05,1.0],'loss':['linear','square','exponential']}
grid=GridSearchCV(AdaBoostRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Users\Raji\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05, 1.0],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 20, 30, 50]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'learning_rate': 0.01, 'loss': 'linear', 'n_estimators': 50}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.033371      0.003392         0.004240        0.000398
# 1        0.047189      0.001706         0.005041        0.000889
# 2        0.066421      0.001872         0.006617        0.001036
# 3        0.106539      0.001366         0.008242        0.000260
# 4        0.025625      0.000794         0.003478        0.001055
# 5        0.045534      0.001414         0.006600        0.001637
# 6        0.079491      0.011126         0.006652        0.000896
# 7        0.176816      0.066980         0.031173        0.023994
# 8        0.064086      0.024996         0.006349        0.003019
# 9        0.061571      0.014305         0.005088        0.001570
# 10       0.115897      0.017975         0.010703        0.001503
# 11       0.175314      0.034249         0.011557        0.001925
# 12       0.053922      0.017317         0.004656        0.001177
# 13       0.048131      0.004263         0.004776        0.001214
# 14       0.071330      0.003153         0.008640        0.003365
# 15       0.109761      0.004103         0.009286        0.000612
# 16       0.023638      0.001645         0.004325        0.000404
# 17       0.044422      0.001731         0.005741        0.000673
# 18       0.064241      0.000992         0.007200        0.001159
# 19       0.110353      0.003279         0.008271        0.000574
# 20       0.024036      0.000712         0.002691        0.000896
# 21       0.044883      0.000874         0.005220        0.000802
# 22       0.066650      0.002098         0.006182        0.001055
# 23       0.108401      0.001737         0.009879        0.000726
# 24       0.025546      0.002239         0.004625        0.001359
# 25       0.047158      0.003176         0.005333        0.001684
# 26       0.067398      0.001346         0.006183        0.000236
# 27       0.107467      0.001779         0.009525        0.001022
# 28       0.023748      0.000843         0.003668        0.000865
# 29       0.044832      0.000448         0.005082        0.000907
# 30       0.065148      0.001240         0.006078        0.000247
# 31       0.107103      0.002616         0.008986        0.001329
# 32       0.025070      0.001713         0.002863        0.001048
# 33       0.046275      0.000975         0.004212        0.000394
# 34       0.066975      0.001167         0.006387        0.000439
# 35       0.106687      0.001754         0.009990        0.001020
# 36       0.021881      0.001656         0.002863        0.001167
# 37       0.024383      0.005396         0.004026        0.001153
# 38       0.020174      0.003402         0.002586        0.000704
# 39       0.028550      0.006539         0.005866        0.002066
# 40       0.024546      0.002051         0.004369        0.000704
# 41       0.042859      0.001602         0.004898        0.001117
# 42       0.062309      0.001001         0.005920        0.000642
# 43       0.099474      0.001949         0.009267        0.001197
# 44       0.023564      0.000820         0.003999        0.000672
# 45       0.043485      0.001891         0.005231        0.000937
# 46       0.065486      0.003279         0.006077        0.001267
# 47       0.112158      0.002692         0.009249        0.001135
#
#     param_learning_rate   param_loss  param_n_estimators  \
# 0                  0.10       linear                  10
# 1                  0.10       linear                  20
# 2                  0.10       linear                  30
# 3                  0.10       linear                  50
# 4                  0.10       square                  10
# 5                  0.10       square                  20
# 6                  0.10       square                  30
# 7                  0.10       square                  50
# 8                  0.10  exponential                  10
# 9                  0.10  exponential                  20
# 10                 0.10  exponential                  30
# 11                 0.10  exponential                  50
# 12                 0.01       linear                  10
# 13                 0.01       linear                  20
# 14                 0.01       linear                  30
# 15                 0.01       linear                  50
# 16                 0.01       square                  10
# 17                 0.01       square                  20
# 18                 0.01       square                  30
# 19                 0.01       square                  50
# 20                 0.01  exponential                  10
# 21                 0.01  exponential                  20
# 22                 0.01  exponential                  30
# 23                 0.01  exponential                  50
# 24                 0.05       linear                  10
# 25                 0.05       linear                  20
# 26                 0.05       linear                  30
# 27                 0.05       linear                  50
# 28                 0.05       square                  10
# 29                 0.05       square                  20
# 30                 0.05       square                  30
# 31                 0.05       square                  50
# 32                 0.05  exponential                  10
# 33                 0.05  exponential                  20
# 34                 0.05  exponential                  30
# 35                 0.05  exponential                  50
# 36                 1.00       linear                  10
# 37                 1.00       linear                  20
# 38                 1.00       linear                  30
# 39                 1.00       linear                  50
# 40                 1.00       square                  10
# 41                 1.00       square                  20
# 42                 1.00       square                  30
# 43                 1.00       square                  50
# 44                 1.00  exponential                  10
# 45                 1.00  exponential                  20
# 46                 1.00  exponential                  30
# 47                 1.00  exponential                  50
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.874063
# 1   {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.865333
# 2   {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.856730
# 3   {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.848010
# 4   {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.867763
# 5   {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.857608
# 6   {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.843214
# 7   {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.804977
# 8   {'learning_rate': 0.1, 'loss': 'exponential', ...           0.869559
# 9   {'learning_rate': 0.1, 'loss': 'exponential', ...           0.866084
# 10  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.865629
# 11  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.846474
# 12  {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.874187
# 13  {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.869487
# 14  {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.870476
# 15  {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.875569
# 16  {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.879558
# 17  {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.874015
# 18  {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.872931
# 19  {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.871078
# 20  {'learning_rate': 0.01, 'loss': 'exponential',...           0.880374
# 21  {'learning_rate': 0.01, 'loss': 'exponential',...           0.879732
# 22  {'learning_rate': 0.01, 'loss': 'exponential',...           0.871910
# 23  {'learning_rate': 0.01, 'loss': 'exponential',...           0.875732
# 24  {'learning_rate': 0.05, 'loss': 'linear', 'n_e...           0.872548
# 25  {'learning_rate': 0.05, 'loss': 'linear', 'n_e...           0.873850
# 26  {'learning_rate': 0.05, 'loss': 'linear', 'n_e...           0.867799
# 27  {'learning_rate': 0.05, 'loss': 'linear', 'n_e...           0.859232
# 28  {'learning_rate': 0.05, 'loss': 'square', 'n_e...           0.868814
# 29  {'learning_rate': 0.05, 'loss': 'square', 'n_e...           0.869887
# 30  {'learning_rate': 0.05, 'loss': 'square', 'n_e...           0.867857
# 31  {'learning_rate': 0.05, 'loss': 'square', 'n_e...           0.853209
# 32  {'learning_rate': 0.05, 'loss': 'exponential',...           0.873274
# 33  {'learning_rate': 0.05, 'loss': 'exponential',...           0.869405
# 34  {'learning_rate': 0.05, 'loss': 'exponential',...           0.869972
# 35  {'learning_rate': 0.05, 'loss': 'exponential',...           0.863453
# 36  {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.837873
# 37  {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.815595
# 38  {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.838061
# 39  {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.833152
# 40  {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.671441
# 41  {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.597800
# 42  {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.570202
# 43  {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.530442
# 44  {'learning_rate': 1.0, 'loss': 'exponential', ...           0.809003
# 45  {'learning_rate': 1.0, 'loss': 'exponential', ...           0.729474
# 46  {'learning_rate': 1.0, 'loss': 'exponential', ...           0.686925
# 47  {'learning_rate': 1.0, 'loss': 'exponential', ...           0.621735
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.796676           0.873493           0.832565
# 1            0.797806           0.864239           0.829985
# 2            0.792488           0.860519           0.821600
# 3            0.784315           0.852140           0.819403
# 4            0.791131           0.869286           0.831515
# 5            0.792054           0.856404           0.828426
# 6            0.782042           0.842048           0.815127
# 7            0.741714           0.807250           0.790252
# 8            0.795554           0.875561           0.832694
# 9            0.793839           0.870332           0.829629
# 10           0.796678           0.864247           0.827008
# 11           0.788633           0.850456           0.819585
# 12           0.782844           0.875467           0.829075
# 13           0.797134           0.878906           0.830745
# 14           0.798639           0.880607           0.827562
# 15           0.799554           0.879617           0.831261
# 16           0.786982           0.884378           0.831415
# 17           0.788523           0.881753           0.828898
# 18           0.790083           0.879225           0.830098
# 19           0.797004           0.877261           0.829931
# 20           0.781655           0.875086           0.828897
# 21           0.791242           0.883591           0.828272
# 22           0.788875           0.878517           0.827953
# 23           0.796942           0.880804           0.829259
# 24           0.788324           0.881886           0.829459
# 25           0.798351           0.877957           0.828904
# 26           0.797553           0.874069           0.830452
# 27           0.794088           0.866349           0.827371
